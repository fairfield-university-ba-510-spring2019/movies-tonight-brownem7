# %% [markdown]
# # Movies Tonight Part 4: A few SELECT queries
# __Use `%%sql` magic to write the queries listed below.__

# %%
# load %sql magic extension
# %load_ext sql

# initialize a database connection; may have to adjust username and password 
# %sql sqlite:///Movies.db
# Out:
# 'Connected: @Movies.db'

# %% [markdown]
# **1. Write a select query that returns the MovieTitle, TheaterName, and Showtime for each movie showing.**
# The query should use `JOIN` syntax as described in your textbook. Also, use aliases ( `… AS …` ) to make sure that column names match exactly what is asked for.

# %%
# %%sql
# SELECT MTitle as MovieTitle, STime as Showtime , TName as TheaterName
# FROM  MOVIES
#      JOIN SHOWS USING (MID)
#      JOIN THEATERS USING (TID)
# Out:
#  * sqlite:///Movies.db
# Done.
# [('Associate, The', '4:20 PM', 'Akarakian Theatres Moreno 4 Cinemas'),
#  ('Associate, The', '7:20 PM', 'Akarakian Theatres Moreno 4 Cinemas'),
#  ('Associate, The', '9:40 PM', 'Akarakian Theatres Moreno 4 Cinemas'),
#  ('Ghost & The Darkness, The', '5:10 PM', 'Akarakian Theatres Moreno 4 Cinemas'),
#  ('Ghost & The Darkness, The', '9:00 PM', 'Akarakian Theatres Moreno 4 Cinemas'),
#  ('Ghost & The Darkness, The', '9:05 PM', 'Akarakian Theatres Moreno 4 Cinemas'),
#  ('Independence Day', '7:00 PM', 'Akarakian Theatres Moreno 4 Cinemas'),
#  ('Associate, The', '4:40 PM', 'Cinema Star The Ultraplex 14'),
#  ('Associate, The', '7:30 PM', 'Cinema Star The Ultraplex 14'),
#  ('D3: The Mighty Ducks', '2:30 PM', 'Cinema Star The Ultraplex 14'),
#  ('Dear God', '5:15 PM', 'Cinema Star The Ultraplex 14'),
#  ('Dear God', '7:45 PM', 'Cinema Star The Ultraplex 14'),
#  ('First Wives Club, The', '5:30 PM', 'Cinema Star The Ultraplex 14'),
#  ('First Wives Club, The', '8:00 PM', 'Cinema Star The Ultraplex 14'),
#  ('Ghost & The Darkness, The', '5:00 PM', 'Cinema Star The Ultraplex 14'),
#  ('Ghost & The Darkness, The', '7:40 PM', 'Cinema Star The Ultraplex 14'),
#  ('High School High', '4:00 PM', 'Cinema Star The Ultraplex 14'),
#  ('High School High', '6:15 PM', 'Cinema Star The Ultraplex 14'),
#  ('High School High', '8:30 PM', 'Cinema Star The Ultraplex 14'),
#  ('Larger Than Life', '8:20 PM', 'Cinema Star The Ultraplex 14'),
#  ('Mirror Has Two Faces, The', '4:45 PM', 'Cinema Star The Ultraplex 14'),
#  ('Mirror Has Two Faces, The', '5:45 PM', 'Cinema Star The Ultraplex 14'),
#  ('Mirror Has Two Faces, The', '7:45 PM', 'Cinema Star The Ultraplex 14'),
#  ('Mirror Has Two Faces, The', '8:45 PM', 'Cinema Star The Ultraplex 14'),
#  ('Ransom', '4:15 PM', 'Cinema Star The Ultraplex 14'),
#  ('Ransom', '4:45 PM', 'Cinema Star The Ultraplex 14'),
#  ('Ransom', '5:15 PM', 'Cinema Star The Ultraplex 14'),
#  ('Ransom', '7:00 PM', 'Cinema Star The Ultraplex 14'),
#  ('Ransom', '7:30 PM', 'Cinema Star The Ultraplex 14'),
#  ('Ransom', '8:00 PM', 'Cinema Star The Ultraplex 14'),
#  ('Ransom', '9:45 PM', 'Cinema Star The Ultraplex 14'),
#  ('Sleepers', '7:30 PM', 'Cinema Star The Ultraplex 14'),
#  ('Space Jam', '5:00 PM', 'Cinema Star The Ultraplex 14'),
#  ('Space Jam', '6:00 PM', 'Cinema Star The Ultraplex 14'),
#  ('Space Jam', '7:15 PM', 'Cinema Star The Ultraplex 14'),
#  ('Space Jam', '8:15 PM', 'Cinema Star The Ultraplex 14'),
#  ("Stephen King's Thinner", '6:00 PM', 'Cinema Star The Ultraplex 14'),
#  ('Associate, The', '5:00 PM', 'General Cinema Rancho 6'),
#  ('Associate, The', '7:30 PM', 'General Cinema Rancho 6'),
#  ('Dear God', '4:45 PM', 'General Cinema Rancho 6'),
#  ('Dear God', '7:15 PM', 'General Cinema Rancho 6'),
#  ('First Wives Club, The', '5:30 PM', 'General Cinema Rancho 6'),
#  ('First Wives Club, The', '8:00 PM', 'General Cinema Rancho 6'),
#  ('Michael Collins', '4:00 PM', 'General Cinema Rancho 6'),
#  ('Michael Collins', '7:15 PM', 'General Cinema Rancho 6'),
#  ('Romeo & Juliet', '5:15 PM', 'General Cinema Rancho 6'),
#  ('Romeo & Juliet', '7:45 PM', 'General Cinema Rancho 6'),
#  ('Sleepers', '7:00 PM', 'General Cinema Rancho 6'),
#  ('Ghost & The Darkness, The', '10:05 PM', 'Pacific Inland Center'),
#  ('Ghost & The Darkness, The', '5:15 PM', 'Pacific Inland Center'),
#  ('Ghost & The Darkness, The', '7:40 PM', 'Pacific Inland Center'),
#  ('Big Night', '4:40 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Big Night', '7:10 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Big Night', '9:40 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Fly Away Home', '3:50 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Ghost & The Darkness, The', '6:50 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Ghost & The Darkness, The', '9:15 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Independence Day', '6:10 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Independence Day', '9:10 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Michael Collins', '6:20 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Michael Collins', '9:10 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Nutty Professor, The', '4:25 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Nutty Professor, The', '8:05 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Phenomenon', '6:20 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Phenomenon', '9:15 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Romeo & Juliet', '4:30 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Romeo & Juliet', '7:00 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Romeo & Juliet', '9:30 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Set It Off', '4:10 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Set It Off', '6:30 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Set It Off', '9:00 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Surviving Picasso', '6:40 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Surviving Picasso', '9:25 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Very Brady Sequel, A', '6:00 PM', 'SOCAL Canyon Crest Cinema'),
#  ('D3: The Mighty Ducks', '4:15 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Dear God', '6:40 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Dear God', '9:00 PM', 'SOCAL Canyon Springs Cinema'),
#  ('First Wives Club, The', '4:20 PM', 'SOCAL Canyon Springs Cinema'),
#  ('First Wives Club, The', '6:30 PM', 'SOCAL Canyon Springs Cinema'),
#  ('First Wives Club, The', '8:40 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Fly Away Home', '4:50 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Ghost & The Darkness, The', '7:20 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Ghost & The Darkness, The', '9:50 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Romeo & Juliet', '4:30 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Romeo & Juliet', '7:00 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Romeo & Juliet', '9:30 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Set It Off', '4:25 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Set It Off', '6:50 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Set It Off', '9:15 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Sleepers', '5:30 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Sleepers', '8:30 PM', 'SOCAL Canyon Springs Cinema'),
#  ('That Thing You Do', '4:40 PM', 'SOCAL Canyon Springs Cinema'),
#  ('That Thing You Do', '7:15 PM', 'SOCAL Canyon Springs Cinema'),
#  ('That Thing You Do', '9:40 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Mirror Has Two Faces, The', '4:10 PM', 'SOCAL Marketplace Cinema'),
#  ('Mirror Has Two Faces, The', '6:45 PM', 'SOCAL Marketplace Cinema'),
#  ('Mirror Has Two Faces, The', '9:25 PM', 'SOCAL Marketplace Cinema'),
#  ('Ransom', '4:20 PM', 'SOCAL Marketplace Cinema'),
#  ('Ransom', '5:20 PM', 'SOCAL Marketplace Cinema'),
#  ('Ransom', '7:00 PM', 'SOCAL Marketplace Cinema'),
#  ('Ransom', '8:00 PM', 'SOCAL Marketplace Cinema'),
#  ('Ransom', '9:40 PM', 'SOCAL Marketplace Cinema'),
#  ('Space Jam', '4:45 PM', 'SOCAL Marketplace Cinema'),
#  ('Space Jam', '5:50 PM', 'SOCAL Marketplace Cinema'),
#  ('Space Jam', '7:15 PM', 'SOCAL Marketplace Cinema'),
#  ('Space Jam', '8:10 PM', 'SOCAL Marketplace Cinema'),
#  ('Space Jam', '9:30 PM', 'SOCAL Marketplace Cinema'),
#  ('First Wives Club, The', '4:20 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('First Wives Club, The', '7:10 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('First Wives Club, The', '9:30 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('High School High', '5:00 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('High School High', '7:00 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('High School High', '9:00 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('Romeo & Juliet', '4:30 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('Romeo & Juliet', '7:00 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('Romeo & Juliet', '9:45 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('Space Jam', '5:25 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('Space Jam', '7:30 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('Space Jam', '9:35 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('Dear God', '5:15 PM', 'United Artists Riverside Park Sierra'),
#  ('Dear God', '9:25 PM', 'United Artists Riverside Park Sierra'),
#  ('Ghost & The Darkness, The', '7:15 PM', 'United Artists Riverside Park Sierra'),
#  ('Larger Than Life', '7:30 PM', 'United Artists Riverside Park Sierra'),
#  ('Mirror Has Two Faces, The', '10:20 PM', 'United Artists Riverside Park Sierra'),
#  ('Mirror Has Two Faces, The', '4:30 PM', 'United Artists Riverside Park Sierra'),
#  ('Mirror Has Two Faces, The', '7:40 PM', 'United Artists Riverside Park Sierra'),
#  ('Set It Off', '10:05 PM', 'United Artists Riverside Park Sierra'),
#  ('Set It Off', '4:40 PM', 'United Artists Riverside Park Sierra'),
#  ('Set It Off', '7:20 PM', 'United Artists Riverside Park Sierra'),
#  ('Sleepers', '4:20 PM', 'United Artists Riverside Park Sierra'),
#  ('Sleepers', '9:30 PM', 'United Artists Riverside Park Sierra')]

# %% [markdown]
# **2. Write a select query to display the MovieTitle, TheaterName, and Showtime for each show after 7pm.** You can start with a copy of the previous query and then add a `WHERE` clause.

# %%
# %%sql
# SELECT MTitle as MovieTitle, STime as Showtime , TName as TheaterName
# FROM  MOVIES
#      JOIN SHOWS USING (MID)
#      JOIN THEATERS USING (TID)
# WHERE STIME > '7.00PM'
# Out:
#  * sqlite:///Movies.db
# Done.
# [('Associate, The', '7:20 PM', 'Akarakian Theatres Moreno 4 Cinemas'),
#  ('Associate, The', '9:40 PM', 'Akarakian Theatres Moreno 4 Cinemas'),
#  ('Ghost & The Darkness, The', '9:00 PM', 'Akarakian Theatres Moreno 4 Cinemas'),
#  ('Ghost & The Darkness, The', '9:05 PM', 'Akarakian Theatres Moreno 4 Cinemas'),
#  ('Independence Day', '7:00 PM', 'Akarakian Theatres Moreno 4 Cinemas'),
#  ('Associate, The', '7:30 PM', 'Cinema Star The Ultraplex 14'),
#  ('Dear God', '7:45 PM', 'Cinema Star The Ultraplex 14'),
#  ('First Wives Club, The', '8:00 PM', 'Cinema Star The Ultraplex 14'),
#  ('Ghost & The Darkness, The', '7:40 PM', 'Cinema Star The Ultraplex 14'),
#  ('High School High', '8:30 PM', 'Cinema Star The Ultraplex 14'),
#  ('Larger Than Life', '8:20 PM', 'Cinema Star The Ultraplex 14'),
#  ('Mirror Has Two Faces, The', '7:45 PM', 'Cinema Star The Ultraplex 14'),
#  ('Mirror Has Two Faces, The', '8:45 PM', 'Cinema Star The Ultraplex 14'),
#  ('Ransom', '7:00 PM', 'Cinema Star The Ultraplex 14'),
#  ('Ransom', '7:30 PM', 'Cinema Star The Ultraplex 14'),
#  ('Ransom', '8:00 PM', 'Cinema Star The Ultraplex 14'),
#  ('Ransom', '9:45 PM', 'Cinema Star The Ultraplex 14'),
#  ('Sleepers', '7:30 PM', 'Cinema Star The Ultraplex 14'),
#  ('Space Jam', '7:15 PM', 'Cinema Star The Ultraplex 14'),
#  ('Space Jam', '8:15 PM', 'Cinema Star The Ultraplex 14'),
#  ('Associate, The', '7:30 PM', 'General Cinema Rancho 6'),
#  ('Dear God', '7:15 PM', 'General Cinema Rancho 6'),
#  ('First Wives Club, The', '8:00 PM', 'General Cinema Rancho 6'),
#  ('Michael Collins', '7:15 PM', 'General Cinema Rancho 6'),
#  ('Romeo & Juliet', '7:45 PM', 'General Cinema Rancho 6'),
#  ('Sleepers', '7:00 PM', 'General Cinema Rancho 6'),
#  ('Ghost & The Darkness, The', '7:40 PM', 'Pacific Inland Center'),
#  ('Big Night', '7:10 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Big Night', '9:40 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Ghost & The Darkness, The', '9:15 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Independence Day', '9:10 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Michael Collins', '9:10 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Nutty Professor, The', '8:05 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Phenomenon', '9:15 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Romeo & Juliet', '7:00 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Romeo & Juliet', '9:30 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Set It Off', '9:00 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Surviving Picasso', '9:25 PM', 'SOCAL Canyon Crest Cinema'),
#  ('Dear God', '9:00 PM', 'SOCAL Canyon Springs Cinema'),
#  ('First Wives Club, The', '8:40 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Ghost & The Darkness, The', '7:20 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Ghost & The Darkness, The', '9:50 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Romeo & Juliet', '7:00 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Romeo & Juliet', '9:30 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Set It Off', '9:15 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Sleepers', '8:30 PM', 'SOCAL Canyon Springs Cinema'),
#  ('That Thing You Do', '7:15 PM', 'SOCAL Canyon Springs Cinema'),
#  ('That Thing You Do', '9:40 PM', 'SOCAL Canyon Springs Cinema'),
#  ('Mirror Has Two Faces, The', '9:25 PM', 'SOCAL Marketplace Cinema'),
#  ('Ransom', '7:00 PM', 'SOCAL Marketplace Cinema'),
#  ('Ransom', '8:00 PM', 'SOCAL Marketplace Cinema'),
#  ('Ransom', '9:40 PM', 'SOCAL Marketplace Cinema'),
#  ('Space Jam', '7:15 PM', 'SOCAL Marketplace Cinema'),
#  ('Space Jam', '8:10 PM', 'SOCAL Marketplace Cinema'),
#  ('Space Jam', '9:30 PM', 'SOCAL Marketplace Cinema'),
#  ('First Wives Club, The', '7:10 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('First Wives Club, The', '9:30 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('High School High', '7:00 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('High School High', '9:00 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('Romeo & Juliet', '7:00 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('Romeo & Juliet', '9:45 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('Space Jam', '7:30 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('Space Jam', '9:35 PM', 'United Artists Riverside (Galleria) Tyler Mall'),
#  ('Dear God', '9:25 PM', 'United Artists Riverside Park Sierra'),
#  ('Ghost & The Darkness, The', '7:15 PM', 'United Artists Riverside Park Sierra'),
#  ('Larger Than Life', '7:30 PM', 'United Artists Riverside Park Sierra'),
#  ('Mirror Has Two Faces, The', '7:40 PM', 'United Artists Riverside Park Sierra'),
#  ('Set It Off', '7:20 PM', 'United Artists Riverside Park Sierra'),
#  ('Sleepers', '9:30 PM', 'United Artists Riverside Park Sierra')]

# %% [markdown]
# **3. Write a select query to display the cast (actors only) of each movie.** The query should return the Movie Title, Actor Name, MID, and AID.

# %%
# %%sql
# SELECT MTitle as MovieTitle, ARTISTS.NAME as 'Actor Name' , MID , AID
# FROM  MOVIES
#      JOIN CREDITS USING (MID)
#      JOIN ARTISTS USING (AID)
# WHERE CCode  = 'A'
# Out:
#  * sqlite:///Movies.db
# Done.
# [('Associate, The', 'Austin Pendleton', 1, 1),
#  ('Associate, The', 'Bebe Neuwirth', 1, 2),
#  ('Associate, The', 'Dianne Wiest', 1, 3),
#  ('Associate, The', 'Eli Wallach', 1, 4),
#  ('Associate, The', 'Kenny Kerr', 1, 5),
#  ('Associate, The', 'Lainie Kazan', 1, 6),
#  ('Associate, The', 'Tim Daly', 1, 7),
#  ('Associate, The', 'Whoopi Goldberg', 1, 8),
#  ('Ghost & The Darkness, The', 'Bernard Hill', 2, 10),
#  ('Ghost & The Darkness, The', 'Brian McCardie', 2, 11),
#  ('Ghost & The Darkness, The', 'Emily Mortimer', 2, 12),
#  ('Ghost & The Darkness, The', 'Henry Cele', 2, 13),
#  ('Ghost & The Darkness, The', 'John Kani', 2, 14),
#  ('Ghost & The Darkness, The', 'Michael Douglas', 2, 15),
#  ('Ghost & The Darkness, The', 'Tom Wilkinson', 2, 16),
#  ('Ghost & The Darkness, The', 'Val Kilmer', 2, 17),
#  ('Independence Day', 'Bill Pullman', 3, 19),
#  ('Independence Day', 'Bill Smitrovich', 3, 20),
#  ('Independence Day', 'Harvey Fierstein', 3, 21),
#  ('Independence Day', 'Jeff Goldblum', 3, 22),
#  ('Independence Day', 'Judd Hirsch', 3, 23),
#  ('Independence Day', 'Margaret Colin', 3, 24),
#  ('Independence Day', 'Mary McDonnell', 3, 25),
#  ('Independence Day', 'Randy Quaid', 3, 26),
#  ('Independence Day', 'Robert Loggia', 3, 27),
#  ('Independence Day', 'Vivica Fox', 3, 28),
#  ('Independence Day', 'Will Smith', 3, 29),
#  ('D3: The Mighty Ducks', 'Emilio Estevez', 4, 31),
#  ('D3: The Mighty Ducks', 'Heidi Kling', 4, 32),
#  ('D3: The Mighty Ducks', 'Jeffrey Nordling', 4, 33),
#  ('D3: The Mighty Ducks', 'Joss Ackland', 4, 34),
#  ('D3: The Mighty Ducks', 'Rob Lieberman', 4, 35),
#  ('Dear God', 'Greg Kinnear', 5, 36),
#  ('Dear God', 'Hector Elizondo', 5, 37),
#  ('Dear God', 'Jon Seda', 5, 38),
#  ('Dear God', 'Laurie Metcalf', 5, 39),
#  ('Dear God', 'Maria Pitillo', 5, 40),
#  ('Dear God', 'Roscoe Lee Browne', 5, 41),
#  ('Dear God', 'Tim Conway', 5, 42),
#  ('First Wives Club, The', 'Bette Midler', 6, 44),
#  ('First Wives Club, The', 'Diane Keaton', 6, 45),
#  ('First Wives Club, The', 'Goldie Hawn', 6, 46),
#  ('High School High', 'and Louise Fletcher', 7, 48),
#  ('High School High', 'Jon Lovitz', 7, 49),
#  ('High School High', 'Mekhi Phifer', 7, 50),
#  ('High School High', 'Tia Carrera', 7, 51),
#  ('Larger Than Life', 'Bill Murray', 8, 53),
#  ('Larger Than Life', 'Janeane Garofalo', 8, 54),
#  ('Larger Than Life', 'Jeremy Piven', 8, 55),
#  ('Larger Than Life', 'Keith David', 8, 56),
#  ('Larger Than Life', 'Matthew McConaughey', 8, 57),
#  ('Larger Than Life', 'Pat Hingle', 8, 58),
#  ('Mirror Has Two Faces, The', 'Barbra Streisand', 9, 60),
#  ('Mirror Has Two Faces, The', 'Jeff Bridges', 9, 61),
#  ('Mirror Has Two Faces, The', 'Lauren Bacall', 9, 62),
#  ('Mirror Has Two Faces, The', 'Pierce Brosnan', 9, 63),
#  ('Ransom', 'Delroy Lindo', 10, 64),
#  ('Ransom', 'Gary Sinese', 10, 65),
#  ('Ransom', 'Lili Taylor', 10, 66),
#  ('Ransom', 'Mel Gibson', 10, 67),
#  ('Ransom', 'Rene Russo', 10, 68),
#  ('Sleepers', 'Billy Crudup', 11, 70),
#  ('Sleepers', 'Brad Pitt', 11, 71),
#  ('Sleepers', 'Brad Renfro', 11, 72),
#  ('Sleepers', 'Dustin Hoffman', 11, 73),
#  ('Sleepers', 'Jason Patric', 11, 74),
#  ('Sleepers', 'Joseph Perrino', 11, 75),
#  ('Sleepers', 'Kevin Bacon', 11, 76),
#  ('Sleepers', 'Minnie Driver', 11, 77),
#  ('Sleepers', 'Robert De Niro', 11, 78),
#  ('Sleepers', 'Ron Eldard', 11, 79),
#  ('Sleepers', 'Terry Kinney', 11, 80),
#  ('Sleepers', 'Vittorio Gassman', 11, 81),
#  ('Space Jam', 'Bill Murray', 12, 53),
#  ('Space Jam', 'Michael Jordan', 12, 83),
#  ('Space Jam', 'Theresa Randle', 12, 84),
#  ('Space Jam', 'Wayne Knight', 12, 85),
#  ("Stephen King's Thinner", 'Joe Mantegna', 13, 87),
#  ("Stephen King's Thinner", 'Kari Wuhrer', 13, 88),
#  ("Stephen King's Thinner", 'Lucinda Jenney', 13, 89),
#  ("Stephen King's Thinner", 'Michael Constantine', 13, 90),
#  ("Stephen King's Thinner", 'Robert John Burke', 13, 91),
#  ('Michael Collins', 'Aidan Quinn', 14, 93),
#  ('Michael Collins', 'Alan Rickman', 14, 94),
#  ('Michael Collins', 'Julia Roberts', 14, 95),
#  ('Michael Collins', 'Liam Neeson', 14, 96),
#  ('Michael Collins', 'Stephen Rea', 14, 97),
#  ('Romeo & Juliet', 'Claire Danes', 15, 99),
#  ('Romeo & Juliet', 'Diane Venora', 15, 100),
#  ('Romeo & Juliet', 'John Leguizamo', 15, 101),
#  ('Romeo & Juliet', 'Leonardo DiCaprio', 15, 102),
#  ('Romeo & Juliet', 'Paul Rudd', 15, 103),
#  ('Romeo & Juliet', 'Paul Sorvino', 15, 104),
#  ('Big Night', 'Campbell Scott', 16, 106),
#  ('Big Night', 'Ian Holm', 16, 107),
#  ('Big Night', 'Isabella Rossellini', 16, 108),
#  ('Big Night', 'Minnie Driver', 16, 77),
#  ('Big Night', 'Stanley Tucci', 16, 109),
#  ('Big Night', 'Tony Shalhoub', 16, 110),
#  ('Fly Away Home', 'Anna Paquin', 17, 111),
#  ('Fly Away Home', 'Dana Delany', 17, 112),
#  ('Fly Away Home', 'Jeff Daniels', 17, 113),
#  ('Nutty Professor, The', 'Dave Chappelle', 18, 115),
#  ('Nutty Professor, The', 'Eddie Murphy', 18, 116),
#  ('Nutty Professor, The', 'Jada Pinkett', 18, 117),
#  ('Nutty Professor, The', 'James Coburn', 18, 118),
#  ('Nutty Professor, The', 'John Ales', 18, 119),
#  ('Nutty Professor, The', 'Larry Miller', 18, 120),
#  ('Phenomenon', 'Forest Whitaker', 19, 122),
#  ('Phenomenon', 'John Travolta', 19, 123),
#  ('Phenomenon', 'Kyra Sedgwick', 19, 124),
#  ('Phenomenon', 'Robert Duvall', 19, 125),
#  ('Set It Off', 'Blair Underwood', 20, 127),
#  ('Set It Off', 'Jada Pinkett', 20, 117),
#  ('Set It Off', 'John C. McGinley', 20, 128),
#  ('Set It Off', 'Kimberly Elise', 20, 129),
#  ('Set It Off', 'Queen Latifah', 20, 130),
#  ('Set It Off', 'Vivica Fox', 20, 28),
#  ('Surviving Picasso', 'Anthony Hopkins', 21, 132),
#  ('Surviving Picasso', 'Diane Venora', 21, 100),
#  ('Surviving Picasso', 'Joan Plowright', 21, 133),
#  ('Surviving Picasso', 'Julianne Moore', 21, 134),
#  ('Surviving Picasso', 'Natascha McElhone', 21, 135),
#  ('Very Brady Sequel, A', 'Christine Taylor', 22, 137),
#  ('Very Brady Sequel, A', 'Christopher Daniel Barnes', 22, 138),
#  ('Very Brady Sequel, A', 'Gary Cole', 22, 139),
#  ('Very Brady Sequel, A', 'Henriette Mantel', 22, 140),
#  ('Very Brady Sequel, A', 'Jennifer Elise Cox', 22, 141),
#  ('Very Brady Sequel, A', 'Jesse Lee', 22, 142),
#  ('Very Brady Sequel, A', 'Olivia Hack', 22, 143),
#  ('Very Brady Sequel, A', 'Paul Sutera', 22, 144),
#  ('Very Brady Sequel, A', 'Shelley Long', 22, 145),
#  ('Very Brady Sequel, A', 'Tim Matheson', 22, 146),
#  ('D3: The Mighty Ducks', 'Joss AcklandDirected by</B> Rob Lieberma', 4, 148),
#  ('That Thing You Do', 'Ethan Embry', 23, 149),
#  ('That Thing You Do', 'Johnathon Schaech', 23, 150),
#  ('That Thing You Do', 'Steve Zahn', 23, 151),
#  ('That Thing You Do', 'Tom Everett Scott', 23, 152)]

# %% [markdown]
# **4. Write a select query to display the number of distinct movies that each actor appears in.** The query should return the ActorName, MovieCount, and AID. You will need to use use a GROUP BY clause and the COUNT() function.

# %%
# %%sql
# SELECT ARTISTS.NAME as 'Actor Name', COUNT(MTitle) as MovieCoubt, AID
# FROM  MOVIES
#      JOIN CREDITS USING (MID)
#      JOIN ARTISTS USING (AID)
# group by ARTISTS.NAME, AID
# Out:
#  * sqlite:///Movies.db
# Done.
# [('Aidan Quinn', 1, 93),
#  ('Alan Rickman', 1, 94),
#  ('Anna Paquin', 1, 111),
#  ('Anthony Hopkins', 1, 132),
#  ('Arlene Sanford', 1, 147),
#  ('Austin Pendleton', 1, 1),
#  ('Barbra Streisand', 2, 60),
#  ('Barry Levinson', 1, 82),
#  ('Baz Luhrmann', 1, 105),
#  ('Bebe Neuwirth', 1, 2),
#  ('Bernard Hill', 1, 10),
#  ('Bette Midler', 1, 44),
#  ('Bill Murray', 2, 53),
#  ('Bill Pullman', 1, 19),
#  ('Bill Smitrovich', 1, 20),
#  ('Billy Crudup', 1, 70),
#  ('Blair Underwood', 1, 127),
#  ('Brad Pitt', 1, 71),
#  ('Brad Renfro', 1, 72),
#  ('Brian McCardie', 1, 11),
#  ('Campbell Scott', 2, 106),
#  ('Carroll Ballard', 1, 114),
#  ('Christine Taylor', 1, 137),
#  ('Christopher Daniel Barnes', 1, 138),
#  ('Claire Danes', 1, 99),
#  ('Dana Delany', 1, 112),
#  ('Dave Chappelle', 1, 115),
#  ('Delroy Lindo', 1, 64),
#  ('Diane Keaton', 1, 45),
#  ('Diane Venora', 2, 100),
#  ('Dianne Wiest', 1, 3),
#  ('Donald Petrie', 1, 9),
#  ('Dustin Hoffman', 1, 73),
#  ('Eddie Murphy', 1, 116),
#  ('Eli Wallach', 1, 4),
#  ('Emilio Estevez', 1, 31),
#  ('Emily Mortimer', 1, 12),
#  ('Ethan Embry', 1, 149),
#  ('F. Gary Gray', 1, 131),
#  ('Forest Whitaker', 1, 122),
#  ('Garry Marshall', 1, 43),
#  ('Gary Cole', 1, 139),
#  ('Gary Sinese', 1, 65),
#  ('Goldie Hawn', 1, 46),
#  ('Greg Kinnear', 1, 36),
#  ('Hart Bochner', 1, 52),
#  ('Harvey Fierstein', 1, 21),
#  ('Hector Elizondo', 1, 37),
#  ('Heidi Kling', 1, 32),
#  ('Henriette Mantel', 1, 140),
#  ('Henry Cele', 1, 13),
#  ('Howard Franklin', 1, 59),
#  ('Hugh Wilson', 1, 47),
#  ('Ian Holm', 1, 107),
#  ('Isabella Rossellini', 1, 108),
#  ('Jada Pinkett', 2, 117),
#  ('James Coburn', 1, 118),
#  ('James Ivory', 1, 136),
#  ('Janeane Garofalo', 1, 54),
#  ('Jason Patric', 1, 74),
#  ('Jeff Bridges', 1, 61),
#  ('Jeff Daniels', 1, 113),
#  ('Jeff Goldblum', 1, 22),
#  ('Jeffrey Nordling', 1, 33),
#  ('Jennifer Elise Cox', 1, 141),
#  ('Jeremy Piven', 1, 55),
#  ('Jesse Lee', 1, 142),
#  ('Joan Plowright', 1, 133),
#  ('Joe Mantegna', 1, 87),
#  ('Joe Pytka', 1, 86),
#  ('John Ales', 1, 119),
#  ('John C. McGinley', 1, 128),
#  ('John Kani', 1, 14),
#  ('John Leguizamo', 1, 101),
#  ('John Travolta', 1, 123),
#  ('Johnathon Schaech', 1, 150),
#  ('Jon Lovitz', 1, 49),
#  ('Jon Seda', 1, 38),
#  ('Jon Turteltaub', 1, 126),
#  ('Joseph Perrino', 1, 75),
#  ('Joss Ackland', 1, 34),
#  ('Joss AcklandDirected by</B> Rob Lieberma', 1, 148),
#  ('Judd Hirsch', 1, 23),
#  ('Julia Roberts', 1, 95),
#  ('Julianne Moore', 1, 134),
#  ('Kari Wuhrer', 1, 88),
#  ('Keith David', 1, 56),
#  ('Kenny Kerr', 1, 5),
#  ('Kevin Bacon', 1, 76),
#  ('Kimberly Elise', 1, 129),
#  ('Kyra Sedgwick', 1, 124),
#  ('Lainie Kazan', 1, 6),
#  ('Larry Miller', 1, 120),
#  ('Lauren Bacall', 1, 62),
#  ('Laurie Metcalf', 1, 39),
#  ('Leonardo DiCaprio', 1, 102),
#  ('Liam Neeson', 1, 96),
#  ('Lili Taylor', 1, 66),
#  ('Lucinda Jenney', 1, 89),
#  ('Margaret Colin', 1, 24),
#  ('Maria Pitillo', 1, 40),
#  ('Mary McDonnell', 1, 25),
#  ('Matthew McConaughey', 1, 57),
#  ('Mekhi Phifer', 1, 50),
#  ('Mel Gibson', 1, 67),
#  ('Michael Constantine', 1, 90),
#  ('Michael Douglas', 1, 15),
#  ('Michael Jordan', 1, 83),
#  ('Minnie Driver', 2, 77),
#  ('Natascha McElhone', 1, 135),
#  ('Neil Jordan', 1, 98),
#  ('Olivia Hack', 1, 143),
#  ('Pat Hingle', 1, 58),
#  ('Paul Rudd', 1, 103),
#  ('Paul Sorvino', 1, 104),
#  ('Paul Sutera', 1, 144),
#  ('Pierce Brosnan', 1, 63),
#  ('Queen Latifah', 1, 130),
#  ('Randy Quaid', 1, 26),
#  ('Rene Russo', 1, 68),
#  ('Rob Lieberman', 2, 35),
#  ('Robert De Niro', 1, 78),
#  ('Robert Duvall', 1, 125),
#  ('Robert John Burke', 1, 91),
#  ('Robert Loggia', 1, 27),
#  ('Roland Emmerich', 1, 30),
#  ('Ron Eldard', 1, 79),
#  ('Ron Howard', 1, 69),
#  ('Roscoe Lee Browne', 1, 41),
#  ('Shelley Long', 1, 145),
#  ('Stanley Tucci', 2, 109),
#  ('Stephen Hopkins', 1, 18),
#  ('Stephen Rea', 1, 97),
#  ('Steve Zahn', 1, 151),
#  ('Terry Kinney', 1, 80),
#  ('Theresa Randle', 1, 84),
#  ('Tia Carrera', 1, 51),
#  ('Tim Conway', 1, 42),
#  ('Tim Daly', 1, 7),
#  ('Tim Matheson', 1, 146),
#  ('Tom Everett Scott', 1, 152),
#  ('Tom Hanks', 1, 153),
#  ('Tom Holland', 1, 92),
#  ('Tom Shadyac', 1, 121),
#  ('Tom Wilkinson', 1, 16),
#  ('Tony Shalhoub', 1, 110),
#  ('Val Kilmer', 1, 17),
#  ('Vittorio Gassman', 1, 81),
#  ('Vivica Fox', 2, 28),
#  ('Wayne Knight', 1, 85),
#  ('Whoopi Goldberg', 1, 8),
#  ('Will Smith', 1, 29),
#  ('and Louise Fletcher', 1, 48)]

# %% [markdown]
# **5. Write a select query to display only the actors that appear in multiple movies.** The query should return the Actor Name, Movie Count, and AID. You can use the previous select query as a starting point. You will need to add a HAVING clause to do the restriction.

# %%
# %%sql
# SELECT ARTISTS.NAME as 'Actor Name', COUNT(MTitle) as MovieCoubt, AID
# FROM  MOVIES
#      JOIN CREDITS USING (MID)
#      JOIN ARTISTS USING (AID)
# group by ARTISTS.NAME, AID
# HAVING  COUNT(MTitle) > 1
# Out:
#  * sqlite:///Movies.db
# Done.
# [('Barbra Streisand', 2, 60),
#  ('Bill Murray', 2, 53),
#  ('Campbell Scott', 2, 106),
#  ('Diane Venora', 2, 100),
#  ('Jada Pinkett', 2, 117),
#  ('Minnie Driver', 2, 77),
#  ('Rob Lieberman', 2, 35),
#  ('Stanley Tucci', 2, 109),
#  ('Vivica Fox', 2, 28)]

# %% [markdown]
# **6. Write a select query to display directors that also act in their movies.** The query should return the ArtistName, NumDirectorCredits, NumActorCredits, NumDirectorActorCredits. Each count should be calculated separately using a subquery. Note: NumDirectorActorCredits should be greater than 0.

# %%
# %%sql
# SELECT ARTISTS.NAME as 'ArtistName', COUNT((SELECT CCode FROM ARTISTS WHERE CCode ="D")) AS NumDirectorCredits,COUNT((SELECT CCode FROM ARTISTS WHERE CCode = "A")) as NumActorCredits,  COUNT((SELECT CCode FROM ARTISTS)) AS NumDirectorActorCredits
# FROM  MOVIES
#      JOIN CREDITS USING (MID)
#      JOIN ARTISTS USING (AID)
# GROUP BY ARTISTS.NAME
# HAVING NumDirectorACTORCredits != 1 and NumDirectorCredits !=0
# Out:
#  * sqlite:///Movies.db
# Done.
# [('Barbra Streisand', 1, 1, 2),
#  ('Campbell Scott', 1, 1, 2),
#  ('Rob Lieberman', 1, 1, 2),
#  ('Stanley Tucci', 1, 1, 2)]
